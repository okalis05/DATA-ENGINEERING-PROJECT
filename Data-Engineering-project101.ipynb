# %%
#Dependencies
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime
pd.set_option('max_colwidth', 400)

# %% [markdown]
# ## DATA EXTRACTION
# ---
# - Define the path to the netflix_titles_csv
# - Read the file and store it as a pandas dataframe

# %%
#Define the path to the file
netflix_data = Path("/Users/francoiseelismbazoaokala/Documents/projects/DATA-ENGINEERING-PROJECT/Resources/netflix_titles.csv")

#read the file and store into a pandas dataframe
netflix_data_df = pd.read_csv(netflix_data )

#Take a glimpse at the dataset
netflix_data_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                                                                                                                                                                                                                                                                               cast  \
# 0                                                                                                                                                                                                                                                                                                              NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng
# 2                                                                                                                                                              Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 3                                                                                                                                                                                                                                                                                                              NaN
# 4                                                                                                                                                                                                         Mayur More, Jitendra Kumar, Ranjan Raj, Alam Khan, Ahsaas Channa, Revathi Pillai, Urvi Singh, Arun Kumar
#
#          country date_added  release_year rating   duration  \
# 0  United States  25-Sep-21          2020  PG-13     90 min
# 1   South Africa  24-Sep-21          2021  TV-MA  2 Seasons
# 2            NaN  24-Sep-21          2021  TV-MA   1 Season
# 3            NaN  24-Sep-21          2021  TV-MA   1 Season
# 4          India  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                                        listed_in  \
# 0                                                  Documentaries
# 1                International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Action & Adventure
# 3                                         Docuseries, Reality TV
# 4         International TV Shows, Romantic TV Shows, TV Comedies
#
#                                                                                                                                                 description
# 0  As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.
# 1       After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.
# 2        To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.
# 3       Feuds, flirtations and toilet talk go down among the incarcerated women at the Orleans Justice Center in New Orleans on this gritty reality series.
# 4  In a city of coaching centers known to train India’s finest collegiate minds, an earnest but unexceptional student and his friends navigate campus life.

# %%
#Get the summary of the dataset
netflix_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [raw]
# ##summary of report##
# From the dataset summary above we can see that there are some inconsistencies in the dataset.not all the columns have the expected count of 8807.Obviously there are some missing values as well as other data inconsistencies so we'll have to do some cleanup.

# %% [markdown]
# ## DATA CLEANING
# ---
# **In this section , we'll perform the following task.**
# - Get the summary of the the dataset to ensure no lost data encurred during the extraction
# - Drop unwanted columns('description' and 'release_year','country','duration','listed_in','cast','description)
# - remove all the null values
# - remove duplicated values on the show_id column
# - format the 'date_added'columns
# - Rename and reorder all the columns
# - save the cleaned dataframe as netflix_df.csv CSV file.

# %%
# Remove all the null values ,Drop unwanted columns and re_order them.
reduced_df = netflix_data_df[['show_id','title','type','date_added','rating','director']]
reduced_df = reduced_df.dropna()
reduced_df.head()
# Out:
#   show_id                             title     type date_added rating  \
# 0      s1              Dick Johnson Is Dead    Movie  25-Sep-21  PG-13
# 2      s3                         Ganglands  TV Show  24-Sep-21  TV-MA
# 5      s6                     Midnight Mass  TV Show  24-Sep-21  TV-MA
# 6      s7  My Little Pony: A New Generation    Movie  24-Sep-21     PG
# 7      s8                           Sankofa    Movie  24-Sep-21  TV-MA
#
#                         director
# 0                Kirsten Johnson
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima

# %%
#check the data count to ensure that all the noises were dropped.
reduced_df.count()
# Out:
# show_id       6172
# title         6172
# type          6172
# date_added    6172
# rating        6172
# director      6172
# dtype: int64

# %%
#Format the date_added column and get it in the format(dd-mm-yyy)
reduced_df['date_added'] = pd.to_datetime(reduced_df['date_added'], format='mixed')
reduced_df['date_added'] = reduced_df['date_added'].dt.strftime('%Y-%m-%d')
reduced_df.head()
# Out:
#   show_id                             title     type  date_added rating  \
# 0      s1              Dick Johnson Is Dead    Movie  2021-09-25  PG-13
# 2      s3                         Ganglands  TV Show  2021-09-24  TV-MA
# 5      s6                     Midnight Mass  TV Show  2021-09-24  TV-MA
# 6      s7  My Little Pony: A New Generation    Movie  2021-09-24     PG
# 7      s8                           Sankofa    Movie  2021-09-24  TV-MA
#
#                         director
# 0                Kirsten Johnson
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima

# %%
#Capitalize and rename the columns for a more appealing display
netflix_df = reduced_df.rename(columns = {'show_id':'Show_ID','title':'Titles','type':'Categories',
                                'date_added':'Date_Added','rating':'Ratings','director':'Directors'})

netflix_df.head()
# Out:
#   Show_ID                            Titles Categories  Date_Added Ratings  \
# 0      s1              Dick Johnson Is Dead      Movie  2021-09-25   PG-13
# 2      s3                         Ganglands    TV Show  2021-09-24   TV-MA
# 5      s6                     Midnight Mass    TV Show  2021-09-24   TV-MA
# 6      s7  My Little Pony: A New Generation      Movie  2021-09-24      PG
# 7      s8                           Sankofa      Movie  2021-09-24   TV-MA
#
#                        Directors
# 0                Kirsten Johnson
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima

# %%
# save the cleaned dataframe as netflix_df.csv CSV file
netflix_df.to_csv("/Users/francoiseelismbazoaokala/Documents/projects/DATA-ENGINEERING-PROJECT/output-files/netflix.csv", index=False)

# %% [markdown]
# ## DATA CLEANING
# ---
# **In this section , we'll perform the following task.**
# - Get the summary of the the dataset to ensure no lost data encurred during the extraction
# - Drop unwanted columns('description' and 'release_year','country','duration','listed_in','cast','description)
# - remove all the null values
# - remove duplicated values on the show_id column
# - format the 'date_added'columns
# - Rename and reorder all the columns
# - save the cleaned dataframe as netflix_df.csv CSV file.

# %% [markdown]
# ## CREATE THE MOVIE and DATAFRAME
# ---
#
# **Create a movie_df and titles_df ataframes that has the following colums.**
# - Title_ID
# - Titles
# - Categories
# - Date_Added
# - Ratings

# %%
# Create a copy of the netflix_df DataFrame and name it movie_data_df
movie_data_df = netflix_df.copy()
movie_data_df.head()
# Out:
#   Show_ID                            Titles Categories  Date_Added Ratings  \
# 0      s1              Dick Johnson Is Dead      Movie  2021-09-25   PG-13
# 2      s3                         Ganglands    TV Show  2021-09-24   TV-MA
# 5      s6                     Midnight Mass    TV Show  2021-09-24   TV-MA
# 6      s7  My Little Pony: A New Generation      Movie  2021-09-24      PG
# 7      s8                           Sankofa      Movie  2021-09-24   TV-MA
#
#                        Directors
# 0                Kirsten Johnson
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima

# %%
# Extract the columns of interest('Title','Category','Date_Added','Rating')
movie_data_df  = movie_data_df[['Titles','Categories','Date_Added','Ratings']]
movie_data_df.head()
# Out:
#                              Titles Categories  Date_Added Ratings
# 0              Dick Johnson Is Dead      Movie  2021-09-25   PG-13
# 2                         Ganglands    TV Show  2021-09-24   TV-MA
# 5                     Midnight Mass    TV Show  2021-09-24   TV-MA
# 6  My Little Pony: A New Generation      Movie  2021-09-24      PG
# 7                           Sankofa      Movie  2021-09-24   TV-MA

# %%
# Get the unique titles in a list
titles = movie_data_df['Titles'].tolist()
# Get the number of distinct values in the titles list.
title_count = len(titles)
# Create a numpy array of the length of the title_count list.
np_title = np.arange(1,6173)
# Use a list comprehension to add "tid" to each title.
title_id = [f'tid{x}' for x in range(1,6173)]
#create a dataframe with the title and title_id columns
title_df = pd.DataFrame({'Title_ID':title_id , 'Titles':titles})
title_df.head()
# Out:
#   Title_ID                            Titles
# 0     tid1              Dick Johnson Is Dead
# 1     tid2                         Ganglands
# 2     tid3                     Midnight Mass
# 3     tid4  My Little Pony: A New Generation
# 4     tid5                           Sankofa

# %%
#merge title-df and the movie_data_df into a new dataframe named movie_df
movie_df = pd.merge(title_df,movie_data_df,on='Titles',how = 'right')
movie_df.head()
# Out:
#   Title_ID                            Titles Categories  Date_Added Ratings
# 0     tid1              Dick Johnson Is Dead      Movie  2021-09-25   PG-13
# 1     tid2                         Ganglands    TV Show  2021-09-24   TV-MA
# 2     tid3                     Midnight Mass    TV Show  2021-09-24   TV-MA
# 3     tid4  My Little Pony: A New Generation      Movie  2021-09-24      PG
# 4     tid5                           Sankofa      Movie  2021-09-24   TV-MA

# %%
#export the movie_df to a csv file as movie_df.csv
movie_df.to_csv("/Users/francoiseelismbazoaokala/Documents/projects/DATA-ENGINEERING-PROJECT/output-files/movie.csv", index=False)

# %% [markdown]
# ## CREATE THE TITLES DATAFRAME
# ---
# **Create the titles_df dataframe that has the following columns.**
# - Title_ID
# - Show_ID
# - Titles
# - Categories

# %%
#import a copy of the movie_df and netflix_df
df1 = movie_df.copy()
df2 = netflix_df.copy()

# %%
#merge both dataframe on titles column and display the output
titles_data_df = pd.merge(df2,df1)
titles_data_df.head()
# Out:
#   Show_ID                            Titles Categories  Date_Added Ratings  \
# 0      s1              Dick Johnson Is Dead      Movie  2021-09-25   PG-13
# 1      s3                         Ganglands    TV Show  2021-09-24   TV-MA
# 2      s6                     Midnight Mass    TV Show  2021-09-24   TV-MA
# 3      s7  My Little Pony: A New Generation      Movie  2021-09-24      PG
# 4      s8                           Sankofa      Movie  2021-09-24   TV-MA
#
#                        Directors Title_ID
# 0                Kirsten Johnson     tid1
# 1                Julien Leclercq     tid2
# 2                  Mike Flanagan     tid3
# 3  Robert Cullen, José Luis Ucha     tid4
# 4                   Haile Gerima     tid5

# %%
#extract and reorganize the columns 'Show_ID','Titles','Categories','Title_ID'
titles_data_df = titles_data_df[['Show_ID','Title_ID','Categories','Titles']]
titles_data_df.head()
# Out:
#   Show_ID Title_ID Categories                            Titles
# 0      s1     tid1      Movie              Dick Johnson Is Dead
# 1      s3     tid2    TV Show                         Ganglands
# 2      s6     tid3    TV Show                     Midnight Mass
# 3      s7     tid4      Movie  My Little Pony: A New Generation
# 4      s8     tid5      Movie                           Sankofa

# %%
#check for duplicate values
duplicate_titles = titles_data_df.loc[titles_data_df.duplicated(subset=['Show_ID','Title_ID']),'Title_ID'].unique()
duplicate_titles
#get info on the duplicated values
duplicate2 = titles_data_df.loc[titles_data_df["Title_ID"]=='tid3909',:]
duplicate2
# Out:
#      Show_ID Title_ID Categories  Titles
# 2939   s4523  tid3909      Movie  22-Jul
# 2941   s4523  tid3909      Movie  22-Jul
# 2943   s5966  tid3909      Movie  22-Jul
# 2945   s5966  tid3909      Movie  22-Jul

# %%
#remove duplicated show_id
titles_df = titles_data_df[titles_data_df.isin(duplicate_titles)==False]
titles_df.count()
# Out:
# Show_ID       6184
# Title_ID      6168
# Categories    6184
# Titles        6184
# dtype: int64

# %%
titles_df = titles_df.dropna()
titles_df.count()
# Out:
# Show_ID       6168
# Title_ID      6168
# Categories    6168
# Titles        6168
# dtype: int64

# %%
#export the titles_df to a csv file as titles_df.csv
titles_df.to_csv("/Users/francoiseelismbazoaokala/Documents/projects/DATA-ENGINEERING-PROJECT/output-files/titles.csv", index=False)

# %% [markdown]
# ## CREATE THE DIRECTOR DATAFRAME
# ---
# **Create the director table with the following columns**
# - Show_ID
# - Titles
# - Categories
# - Date_Added
# - First_Name
# - Last_Name
# - Ratings
#   The first and last name columns will derive from the Director column

# %%
 #Create a copy of the  DataFrame and name it cast_data_df
director_data_df = netflix_df.copy()
director_data_df.head()
# Out:
#   Show_ID                            Titles Categories  Date_Added Ratings  \
# 0      s1              Dick Johnson Is Dead      Movie  2021-09-25   PG-13
# 2      s3                         Ganglands    TV Show  2021-09-24   TV-MA
# 5      s6                     Midnight Mass    TV Show  2021-09-24   TV-MA
# 6      s7  My Little Pony: A New Generation      Movie  2021-09-24      PG
# 7      s8                           Sankofa      Movie  2021-09-24   TV-MA
#
#                        Directors
# 0                Kirsten Johnson
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima

# %%
#Extract the columns of interest
director_data_df = director_data_df[['Show_ID','Titles','Ratings','Categories','Date_Added','Directors']]
director_data_df.head()
# Out:
#   Show_ID                            Titles Ratings Categories  Date_Added  \
# 0      s1              Dick Johnson Is Dead   PG-13      Movie  2021-09-25
# 2      s3                         Ganglands   TV-MA    TV Show  2021-09-24
# 5      s6                     Midnight Mass   TV-MA    TV Show  2021-09-24
# 6      s7  My Little Pony: A New Generation      PG      Movie  2021-09-24
# 7      s8                           Sankofa   TV-MA      Movie  2021-09-24
#
#                        Directors
# 0                Kirsten Johnson
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima

# %%
director_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6172 entries, 0 to 8806
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Show_ID     6172 non-null   object
#  1   Titles      6172 non-null   object
#  2   Ratings     6172 non-null   object
#  3   Categories  6172 non-null   object
#  4   Date_Added  6172 non-null   object
#  5   Directors   6172 non-null   object
# dtypes: object(6)
# memory usage: 337.5+ KB

# %%
# Split the director coulumn into 2 colums and name each First_Name and 'Last_Name' respectively
#store the directors column in a list
cast_list = director_data_df['Directors'].tolist()

#extract individual names from the director_list
name_list = []
for value in cast_list:
      full_name = value.split(',')
      name_list.append(full_name[-1])
      
#create a variable to store a dictionanry.
actors_dict={}
actors_dict['Directors']=name_list

#create a dataframe
data_df = pd.DataFrame(actors_dict)


#split the names column into 2 columns named First_name and Last_name
data_df[['First_Name','Last_Name']] =data_df['Directors'].str.split(' ',n=1,expand=True)

#Display the dataframe
data_df.head()
# Out:
#          Directors First_Name       Last_Name
# 0  Kirsten Johnson    Kirsten         Johnson
# 1  Julien Leclercq     Julien        Leclercq
# 2    Mike Flanagan       Mike        Flanagan
# 3   José Luis Ucha             José Luis Ucha
# 4     Haile Gerima      Haile          Gerima

# %%
data_df['Last_Name'].fillna(0).count()
# Out:
# 6172

# %%
#merge the data_df and director_data_df dataframes
director_df = pd.merge(data_df,director_data_df).drop_duplicates()
director_df.head()
# Out:
#           Directors First_Name Last_Name Show_ID                Titles  \
# 0   Kirsten Johnson    Kirsten   Johnson      s1  Dick Johnson Is Dead
# 1   Julien Leclercq     Julien  Leclercq      s3             Ganglands
# 2   Julien Leclercq     Julien  Leclercq   s1237            Sentinelle
# 3   Julien Leclercq     Julien  Leclercq   s2669       Earth and Blood
# 10    Mike Flanagan       Mike  Flanagan      s6         Midnight Mass
#
#    Ratings Categories  Date_Added
# 0    PG-13      Movie  2021-09-25
# 1    TV-MA    TV Show  2021-09-24
# 2    TV-MA      Movie  2021-03-05
# 3    TV-MA      Movie  2020-04-17
# 10   TV-MA    TV Show  2021-09-24

# %%
#drop the director column
director_df = director_df[['First_Name','Last_Name','Show_ID','Titles','Ratings','Categories','Date_Added']].dropna()
director_df.head()
# Out:
#    First_Name Last_Name Show_ID                Titles Ratings Categories  \
# 0     Kirsten   Johnson      s1  Dick Johnson Is Dead   PG-13      Movie
# 1      Julien  Leclercq      s3             Ganglands   TV-MA    TV Show
# 2      Julien  Leclercq   s1237            Sentinelle   TV-MA      Movie
# 3      Julien  Leclercq   s2669       Earth and Blood   TV-MA      Movie
# 10       Mike  Flanagan      s6         Midnight Mass   TV-MA    TV Show
#
#     Date_Added
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-03-05
# 3   2020-04-17
# 10  2021-09-24

# %%
#create a unique id column
titles = director_df['Titles']
#get the count of the titles
titles_count = director_df['Titles'].count()
#create a numpy array of the length of titles
np_titles = np.arange(1,5494)
#set the id format
ID = [f'100{x}'for x in range(1,5494)]
#add the id  column to the director_df
id_df= pd.DataFrame({'IDs':ID,'Titles':titles})
# concatenating id_df and director_df along columns
director_df = pd.merge(id_df,director_df)
#display the first5 row
director_df.head()
# Out:
#     IDs                Titles First_Name Last_Name Show_ID Ratings Categories  \
# 0  1001  Dick Johnson Is Dead    Kirsten   Johnson      s1   PG-13      Movie
# 1  1002             Ganglands     Julien  Leclercq      s3   TV-MA    TV Show
# 2  1003            Sentinelle     Julien  Leclercq   s1237   TV-MA      Movie
# 3  1004       Earth and Blood     Julien  Leclercq   s2669   TV-MA      Movie
# 4  1005         Midnight Mass       Mike  Flanagan      s6   TV-MA    TV Show
#
#    Date_Added
# 0  2021-09-25
# 1  2021-09-24
# 2  2021-03-05
# 3  2020-04-17
# 4  2021-09-24

# %%
#Export the new dataframe as cast_df.csv to a csv file.
director_df.to_csv("/Users/francoiseelismbazoaokala/Documents/projects/DATA-ENGINEERING-PROJECT/output-files/director.csv", index=False)
