# %%
#Dependencies
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime
pd.set_option('max_colwidth', 400)

# %% [markdown]
# ## DATA EXTRACTION
# --
# - Define the path to the netflix_titles_csv
# - Read the file and store it as a pandas dataframe

# %%
#Define the path to the file
netflix_data = Path("/Users/francoiseelismbazoaokala/Documents/DATA-ENGINEERING-PROJECT/netflix_titles.csv")

#read the file and store into a pandas dataframe
netflix_data_df = pd.read_csv(netflix_data )

#Take a glimpse at the dataset
netflix_data_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                                                                                                                                                                                                                                                                               cast  \
# 0                                                                                                                                                                                                                                                                                                              NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng
# 2                                                                                                                                                              Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 3                                                                                                                                                                                                                                                                                                              NaN
# 4                                                                                                                                                                                                         Mayur More, Jitendra Kumar, Ranjan Raj, Alam Khan, Ahsaas Channa, Revathi Pillai, Urvi Singh, Arun Kumar
#
#          country date_added  release_year rating   duration  \
# 0  United States  25-Sep-21          2020  PG-13     90 min
# 1   South Africa  24-Sep-21          2021  TV-MA  2 Seasons
# 2            NaN  24-Sep-21          2021  TV-MA   1 Season
# 3            NaN  24-Sep-21          2021  TV-MA   1 Season
# 4          India  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                                        listed_in  \
# 0                                                  Documentaries
# 1                International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Action & Adventure
# 3                                         Docuseries, Reality TV
# 4         International TV Shows, Romantic TV Shows, TV Comedies
#
#                                                                                                                                                 description
# 0  As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.
# 1       After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.
# 2        To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.
# 3       Feuds, flirtations and toilet talk go down among the incarcerated women at the Orleans Justice Center in New Orleans on this gritty reality series.
# 4  In a city of coaching centers known to train India’s finest collegiate minds, an earnest but unexceptional student and his friends navigate campus life.

# %% [markdown]
# ## DATA CLEANING
# --
# **We'll the perform the following task.**
# - Get the summary of the the dataset to ensure no lost data encurred during the extraction
# - Drop unwanted columns('description' and 'release_year','country','duration','listed_in','description)
# - remove all the null values
# - format the 'date_added'columns
# - Rename and reorder all the columns
# - save the cleaned dataframe as netflix_cleaned_df.csv CSV file.

# %%
#Get the summary of the dataset
netflix_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#Drop unwanted columns and remove all the null values
reduced_df = netflix_data_df[['show_id','type','title','director','cast','date_added','rating']]
reduced_df = reduced_df.dropna()
reduced_df.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                                                                                                                                                                                                        cast  \
# 2                                                                                       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# 6                                                                                         Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# 7                                                                                                                           Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri
# 8                                                                                                                                                                                     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood
#
#   date_added rating
# 2  24-Sep-21  TV-MA
# 5  24-Sep-21  TV-MA
# 6  24-Sep-21     PG
# 7  24-Sep-21  TV-MA
# 8  24-Sep-21  TV-14

# %%
#check the data count
reduced_df.count()
# Out:
# show_id       5699
# type          5699
# title         5699
# director      5699
# cast          5699
# date_added    5699
# rating        5699
# dtype: int64

# %%
#Format the date_added column and get it in the format(dd-mm-yyy)
reduced_df['date_added'] = pd.to_datetime(reduced_df['date_added'], format='mixed')
reduced_df['date_added'] = reduced_df['date_added'].dt.strftime('%Y-%m-%d')
reduced_df.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                                                                                                                                                                                                        cast  \
# 2                                                                                       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# 6                                                                                         Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# 7                                                                                                                           Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri
# 8                                                                                                                                                                                     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood
#
#    date_added rating
# 2  2021-09-24  TV-MA
# 5  2021-09-24  TV-MA
# 6  2021-09-24     PG
# 7  2021-09-24  TV-MA
# 8  2021-09-24  TV-14

# %%
#Capitalize and rename the columns for a more appealing display
netflix_df = reduced_df.rename(columns = {'show_id':'Show_ID','type':'Category','title':'Title','director':'Director','cast':'Actors',
                                          'date_added':'Date_Added','rating':'Rating'})

netflix_df.head()
# Out:
#   Show_ID Category                             Title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         Director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                                                                                                                                                                                                      Actors  \
# 2                                                                                       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# 6                                                                                         Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# 7                                                                                                                           Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri
# 8                                                                                                                                                                                     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood
#
#    Date_Added Rating
# 2  2021-09-24  TV-MA
# 5  2021-09-24  TV-MA
# 6  2021-09-24     PG
# 7  2021-09-24  TV-MA
# 8  2021-09-24  TV-14

# %%
#Reorder the columns
netflix_df = netflix_df[['Show_ID','Title','Category','Date_Added','Rating','Director','Actors']]
netflix_df.head()
# Out:
#   Show_ID                             Title Category  Date_Added Rating  \
# 2      s3                         Ganglands  TV Show  2021-09-24  TV-MA
# 5      s6                     Midnight Mass  TV Show  2021-09-24  TV-MA
# 6      s7  My Little Pony: A New Generation    Movie  2021-09-24     PG
# 7      s8                           Sankofa    Movie  2021-09-24  TV-MA
# 8      s9     The Great British Baking Show  TV Show  2021-09-24  TV-14
#
#                         Director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                                                                                                                                                                                                      Actors
# 2                                                                                       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# 6                                                                                         Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# 7                                                                                                                           Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri
# 8                                                                                                                                                                                     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood

# %%
# save the cleaned dataframe as netflix_df.csv CSV file
netflix_df.to_csv("/Users/francoiseelismbazoaokala/Documents/DATA-ENGINEERING-PROJECT/output1", index=False)

# %% [markdown]
# ## CREATE THE MOVIE TABLE
# --
# ** Create a movie_df dataframe that has the following colums
# - Title_ID
# - Title
# - Category
# - Date_Added
# - Rating

# %%
# Create a copy of the netflix_cleaned_df DataFrame and name it movie_data_df
movie_data_df = netflix_df.copy()
movie_data_df.head()
# Out:
#   Show_ID                             Title Category  Date_Added Rating  \
# 2      s3                         Ganglands  TV Show  2021-09-24  TV-MA
# 5      s6                     Midnight Mass  TV Show  2021-09-24  TV-MA
# 6      s7  My Little Pony: A New Generation    Movie  2021-09-24     PG
# 7      s8                           Sankofa    Movie  2021-09-24  TV-MA
# 8      s9     The Great British Baking Show  TV Show  2021-09-24  TV-14
#
#                         Director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                                                                                                                                                                                                      Actors
# 2                                                                                       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# 6                                                                                         Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# 7                                                                                                                           Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri
# 8                                                                                                                                                                                     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood

# %%
# Extract the column of interest('Title','Category','Date_Added','Rating')
movie_data_df  = movie_data_df[['Title','Category','Date_Added','Rating']]
movie_data_df.head()
# Out:
#                               Title Category  Date_Added Rating
# 2                         Ganglands  TV Show  2021-09-24  TV-MA
# 5                     Midnight Mass  TV Show  2021-09-24  TV-MA
# 6  My Little Pony: A New Generation    Movie  2021-09-24     PG
# 7                           Sankofa    Movie  2021-09-24  TV-MA
# 8     The Great British Baking Show  TV Show  2021-09-24  TV-14

# %%
# Get the unique genres in a list
titles = movie_data_df['Title'].tolist()
# Get the number of distinct values in the genre list.
title_count = len(titles)
# Create a numpy array of the length of the title_count list.
np_title = np.arange(1,5700)
# Use a list comprehension to add "tid" to each title.
title_id = [f'tid{x}' for x in range(1,5700)]
#create a dataframe with the title and title_id columns
title_df = pd.DataFrame({'Titles_ID':title_id , 'Title':titles})
title_df.head()
# Out:
#   Titles_ID                             Title
# 0      tid1                         Ganglands
# 1      tid2                     Midnight Mass
# 2      tid3  My Little Pony: A New Generation
# 3      tid4                           Sankofa
# 4      tid5     The Great British Baking Show

# %%
#merge title-df and the movie_data_df into a new dataframe named movie_df
movie_df = pd.merge(title_df,movie_data_df,on='Title')
movie_df.head()
# Out:
#   Titles_ID                             Title Category  Date_Added Rating
# 0      tid1                         Ganglands  TV Show  2021-09-24  TV-MA
# 1      tid2                     Midnight Mass  TV Show  2021-09-24  TV-MA
# 2      tid3  My Little Pony: A New Generation    Movie  2021-09-24     PG
# 3      tid4                           Sankofa    Movie  2021-09-24  TV-MA
# 4      tid5     The Great British Baking Show  TV Show  2021-09-24  TV-14

# %%
#Export the new dataframe as genre_df.csv to a csv file.
movie_df.to_csv("/Users/francoiseelismbazoaokala/Documents/DATA-ENGINEERING-PROJECT/output2", index=False)

# %% [markdown]
# ##CREATE THE CAST TABLE
# --
# ** Create the cast_data_df with the following columns
# - Show_ID
# - Title
# - First_Name
# - Last_Name

# %%
 #Create a copy of the  DataFrame and name it cast_data_df
director_data_df = netflix_df.copy()
director_data_df.head()
# Out:
#   Show_ID                             Title Category  Date_Added Rating  \
# 2      s3                         Ganglands  TV Show  2021-09-24  TV-MA
# 5      s6                     Midnight Mass  TV Show  2021-09-24  TV-MA
# 6      s7  My Little Pony: A New Generation    Movie  2021-09-24     PG
# 7      s8                           Sankofa    Movie  2021-09-24  TV-MA
# 8      s9     The Great British Baking Show  TV Show  2021-09-24  TV-14
#
#                         Director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                                                                                                                                                                                                      Actors
# 2                                                                                       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# 6                                                                                         Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# 7                                                                                                                           Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri
# 8                                                                                                                                                                                     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood

# %%
#Grab the following columns['Show_ID','Title','Actors']
cast_data_df = netflix_df[['Show_ID','Title','Actors']]
cast_data_df.head()
# Out:
#   Show_ID                             Title  \
# 2      s3                         Ganglands
# 5      s6                     Midnight Mass
# 6      s7  My Little Pony: A New Generation
# 7      s8                           Sankofa
# 8      s9     The Great British Baking Show
#
#                                                                                                                                                                                                                                      Actors
# 2                                                                                       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# 6                                                                                         Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# 7                                                                                                                           Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra Duah, Nick Medley, Mutabaruka, Afemo Omilami, Reggie Carter, Mzuri
# 8                                                                                                                                                                                     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Hollywood

# %%
# Split the cast coulumn into 2 colums and name each First_Name and 'Last_Name' respectively
#store the actors column in to a list
cast_list = cast_data_df['Actors'].tolist()
actors = []
for actor_list in cast_list:
    temp = actor_list.split(',')
    for i in temp:
        actors.append(i.strip())
        
#Add the newly created columns to the dataframe and name it cast_df
first_name = []
last_name = []

for name in actors:
     full_name = name.split(' ')
#    print(full_name)
    
     first_name.append(full_name[0])
     last_name.append(full_name[-1])
     print(first_name)
     print(f'-----------------------')
     print(last_name)
#add the names columns to the cast_data_df by a merge
#pd = pd.DataFrame({'First_name':first_name})
#pd

#split the names column into 2 columns named First_name and Last_name

#re_organize the columns  

#Display the dataframe
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
     print(first_name)
     print(f'-----------------------')
     print(last_name)
# Out:
# ['Sami', 'Tracy', 'Samuel', 'Nabiha', 'Sofia', 'Salim', 'Noureddine', 'Geert', 'Bakary', 'Kate', 'Zach', 'Hamish', 'Henry', 'Kristin', 'Samantha', 'Igby', 'Rahul', 'Annarah', 'Annabeth', 'Alex', 'Rahul', 'Matt', 'Michael', 'Crystal', 'Louis', 'Vanessa', 'Kimiko', 'James', 'Sofia', 'Liza', 'Ken', 'Elizabeth', 'Jane', 'Michael', 'Phil', 'Kofi', 'Oyafunmike', 'Alexandra', 'Nick', 'Mutabaruka', 'Afemo', 'Reggie', 'Mzuri', 'Mel', 'Sue', 'Mary', 'Paul', 'Melissa', 'Chris', 'Kevin', 'Timothy', 'Daveed', 'Skyler', 'Laura', 'Rosalind', 'Kimberly', 'Loretta', 'Ravi', 'Sukollawat', 'Sushar', 'Pavarit', 'Sahajak', 'Suthipongse', 'Bhasaworn', 'Daweerit', 'Waratthaya', 'Kittiphoom', 'Abhicha', 'Nophand', 'Kittipong', 'Arisara', 'Jaytiya', 'Pantipa', 'Panupan', 'Kungtap', 'Phumphat', 'Issara', 'Keerati', 'Panjai', 'Supranee', 'Suda', 'Visaka', 'Pitchatorn', 'Luna', 'Jannis', 'Milan', 'Edin', 'Anna', 'Marlon', 'Victor', 'Fleur', 'Aziz', 'Mélanie', 'Elizaveta', 'Klara', 'Lucca', 'Júlia', 'Marcus', 'Kiria', 'Fernanda', 'Gabriel', 'Caio', 'Leonardo', 'Jade', 'Freida', 'Logan', 'Robert', 'Megan', 'Sarah', 'Hayes', 'Mark', 'Brandon', 'Antonio', 'Clint', 'Kamal', 'Meena', 'Gemini', 'Heera', 'Nassar', 'S.P.', 'Maisie', 'Paul', 'Kerry', 'AC', 'Prashanth', 'Aishwarya', 'Sri', 'Nassar', 'Arvind', 'Kajol', 'Prabhu', 'Nassar', 'S.P.', 'Girish', 'Adam', 'Kevin', 'Chris', 'David', 'Rob', 'Salma', 'Maria', 'Maya', 'Colin', 'Tim', 'Joyce', 'Keri', 'Josh', 'J.K.', 'Dakota', 'Kadan', 'L.J.', 'Rich', 'Myndy', 'Annie', 'Jake', 'Liam', 'Gary', 'Amber', 'Harrison', 'Lucas', 'Embeth', 'Julian', 'Josh', 'Richard', 'Angela', 'Abhishek', 'Rinku', 'Delzad', 'Kunal', 'Zoya', 'Nikhil', 'Palomi', 'Adrian', 'Elena', 'Judith', 'Valeriu', 'Tudor', 'Virgil', 'Radu', 'Petronela', 'Bogdan', 'Cristian', 'Gilles', 'Karim', 'François', 'Adèle', 'Kenza', 'Cyril', 'Michaël', 'Idir', 'Vincent', 'Jean-Yves', 'Billy', 'Ron', 'Qu', 'Terry', 'Vanness', 'Jin', 'Philip', 'Xia', 'Yu', 'Roy', 'Robert', 'Richard', 'Lorraine', 'Murray', 'Carl', 'Jeffrey', 'Susan', 'Jonathan', 'Ted', 'Roy', 'Lorraine', 'Murray', 'Joseph', 'Jeffrey', 'Collin', 'Ann', 'Mark', 'Barry', 'Susan', 'Dennis', 'Bess', 'Simon', 'Louis', 'John', 'Lea', 'P.H.', 'Dan', 'Liz', 'Lisa', 'Lorraine', 'Lance', 'Mario', 'Karen', 'Michael', 'Judith', 'Mitchell', 'Lynn', 'Denzel', 'Ryan', 'Vera', 'Brendan', 'Sam', 'Rubén', 'Nora', 'Robert', 'Liam', 'Joel', 'Osas', 'Ini', 'Kemi', 'Toni', 'Ebenezer', 'Eso', 'Patrick', 'Karibi', 'Temisan', 'Timini', 'Denzel', 'Ethan', 'Scott', 'Tom', 'Harris', 'Raymond', 'Cliff', 'Dr.', 'Snoop', 'Macy', 'Eva', 'Kappei', 'Satsuki', 'Mieko', 'Koji', 'Houko', 'Kumiko', 'Noriko', 'Kenichi', 'Toshiyuki', 'Izumi', 'Kappei', 'Satsuki', 'Koji', 'Houko', 'Kumiko', 'Ken', 'Akio', 'Kikuko', 'Kappei', 'Satsuki', 'Koji', 'Houko', 'Kumiko', 'Noriko', 'Ken', 'Cho', 'Mamiko', 'Nobutoshi', 'Kappei', 'Satsuki', 'Koji', 'Houko', 'Kumiko', 'Kenichi', 'Noriko', 'Hisako', 'Ken', 'Tomokazu', 'Junko', 'Chie', 'Rikiya', 'Kazuhiko', 'Masaki', 'Mie', 'Yuichi', 'Kengo', 'Kosei', 'Masako', 'Junko', 'Chie', 'Noriaki', 'Unsho', 'Motoko', 'Kazuhiko', 'Rikiya', 'Showtaro', 'Nana', 'Satoshi', 'Shinji', 'Junko', 'Chie', 'Kazuhiko', 'Satoshi', 'Showtaro', 'Kentaro', 'Ryoka', 'Kohsuke', 'Nana', 'Shinji', 'Yoichi', 'Koichi', 'Yukari', 'Junko', 'Chie', 'Yoichi', 'Koichi', 'Ayumi', 'Keisuke', 'Daisuke', 'Fumiko', 'Hidetoshi', 'Tetsuya', 'Kisho', 'Miyuki', 'Katsuyuki', 'Masako', 'Keiko', 'Masashi', 'Kazuhiko', 'Showtaro', 'Romi', 'Daisuke', 'Seizo', 'Junko', 'Chie', 'Satoshi', 'Rikiya', 'Nobuaki', 'Kenji', 'Keiko', 'Saori', 'Yumi', 'Yuko', 'Fujiko', 'Mutsumi', 'Mayuki', 'Toshiyuki', 'Junko', 'Gamon', 'Chie', 'Showtaro', 'Akira', 'Yasuyuki', 'Urara', 'Sachiko', 'Houko', 'Takako', 'Junko', 'Chie', 'Yoichi', 'Kazuhiko', 'Akio', 'Kyousuke', 'Marika', 'Umeji', 'Masashi', 'Hisao', 'Junko', 'Noriaki', 'Chie', 'Kazuhiko', 'Yuhko', 'Tsutomu', 'Hirotaka', 'Jun', 'Harii', 'Ikuo', 'Winslow', 'Lidya', 'Krysten', 'Michael', 'Evan', 'Erin', 'Jeff', 'Fred',  ...
# -----------------------
# ['Bouajila', 'Gotoas', 'Jouy', 'Akkari', 'Lesaffre', 'Kechiouche', 'Farihi', 'Rampelberg', 'Diombera', 'Siegel', 'Gilford', 'Linklater', 'Thomas', 'Lehman', 'Sloyan', 'Rigney', 'Kohli', 'Cymone', 'Gish', 'Essoe', 'Abburi', 'Biedel', 'Trucco', 'Balint', 'Oliver', 'Hudgens', 'Glenn', 'Marsden', 'Carson', 'Koshy', 'Jeong', 'Perkins', 'Krakowski', 'McKean', 'LaMarr', 'Ghanaba', 'Ogunlano', 'Duah', 'Medley', 'Mutabaruka', 'Omilami', 'Carter', 'Mzuri', 'Giedroyc', 'Perkins', 'Berry', 'Hollywood', 'McCarthy', "O'Dowd", 'Kline', 'Olyphant', 'Diggs', 'Gisondo', 'Harrier', 'Chao', 'Quinn', 'Devine', 'Kapoor', 'Kanarot', 'Manaying', 'Mongkolpisit', 'Boonthanakit', 'Thatphithakkul', 'Bawronkirati', 'Chullasapya', 'Wongchayaporn', 'Wongpentak', 'Thanachanun', 'Boonyai', 'Khamsat', 'Wongchalee', 'Naiwattanakul', 'Arunwattanachai', 'Jantanawong', 'Saelim', 'Chartsuriyakiat', 'Veranitinunt', 'Sivakuae', 'Sirisuwan', 'Charoenpol', 'Chuenban', 'Banhansupavat', 'Santinatornkul', 'Wedler', 'Niewöhner', 'Peschel', 'Hasanović', 'Fialová', 'Boess', 'Boccard', 'Geffrier', 'Dyab', 'Fouché', 'Maximová', 'Castanho', 'Picon', 'Gomes', 'Bessa', 'Malheiros', 'Concon', 'Lima', 'Cabral', 'Cidade', 'Cardozo', 'Pinto', 'Marshall-Green', 'Burke', 'Kelly', 'Minnich', 'Hargrove', 'Sivertsen', 'Fierro', 'Valles', 'Obenchain', 'Hassan', 'Meena', 'Ganesan', 'Rajgopal', 'Nassar', 'Balasubrahmanyam', 'Benson', 'Killam', 'Gudjohnsen', 'Lim', 'Prashanth', 'Bachchan', 'Lakshmi', 'Nassar', 'Swamy', 'Kajol', 'Deva', 'Nassar', 'Balasubrahmanyam', 'Karnad', 'Sandler', 'James', 'Rock', 'Spade', 'Schneider', 'Hayek', 'Bello', 'Rudolph', 'Quinn', 'Meadows', 'Patten', 'Russell', 'Hamilton', 'Simmons', 'Goyo', 'Rockett', 'Benet', 'Hutchman', 'Crist', 'Thurman', 'Brennan', 'Hemsworth', 'Oldman', 'Heard', 'Ford', 'Till', 'Davidtz', 'McMahon', 'Holloway', 'Dreyfuss', 'Sarafyan', 'Banerjee', 'Rajguru', 'Hiwale', 'Kapoor', 'Hussain', 'Dwivedi', 'Ghosh', 'Titieni', 'Purea', 'State', 'Andriuță', 'Smoleanu', 'Aioanei', 'Botar', 'Grigorescu', 'Nechifor', 'Bota', 'Lellouche', 'Leklou', 'Civil', 'Exarchopoulos', 'Fortas', 'Lecomte', 'Abiteboul', 'Azougli', 'Darmuzey', 'Berteloot', 'Magnussen', 'Yuan', 'Jingjing', 'Chen', 'Wu', 'Xing', 'Ng', 'Yu', 'Xia', 'Scheider', 'Shaw', 'Dreyfuss', 'Gary', 'Hamilton', 'Gottlieb', 'Kramer', 'Backlinie', 'Filley', 'Grossman', 'Scheider', 'Gary', 'Hamilton', 'Mascolo', 'Kramer', 'Paxton', 'Dusenberry', 'Gruner', 'Coe', 'French', 'Quaid', 'Armstrong', 'MacCorkindale', 'Jr.', 'Putch', 'Thompson', 'Moriarty', 'Blasko', 'Morris', 'Maurer', 'Gary', 'Guest', 'Peebles', 'Young', 'Caine', 'Barsi', 'Anderson', 'Whitfield', 'Washington', 'Reynolds', 'Farmiga', 'Gleeson', 'Shepard', 'Blades', 'Arnezeder', 'Patrick', 'Cunningham', 'Kinnaman', 'Ighodaro', 'Dima-Okojie', 'Akindoju', 'Tones', 'Eno', 'DIke', 'Diabuah', 'Fubara', 'Emmanuel', 'Egbuson', 'Washington', 'Hawke', 'Glenn', 'Berenger', 'Yulin', 'Barry', 'Curtis', 'Dre', 'Dogg', 'Gray', 'Mendes', 'Yamaguchi', 'Yukino', 'Harada', 'Tsujitani', 'Kuwashima', 'Watanabe', 'Hidaka', 'Ogata', 'Morikawa', 'Ogami', 'Yamaguchi', 'Yukino', 'Tsujitani', 'Kuwashima', 'Watanabe', 'Narita', 'Otsuka', 'Inoue', 'Yamaguchi', 'Yukino', 'Tsujitani', 'Kuwashima', 'Watanabe', 'Hidaka', 'Narita', 'Cho', 'Noto', 'Canna', 'Yamaguchi', 'Yukino', 'Tsujitani', 'Kuwashima', 'Watanabe', 'Ogata', 'Hidaka', 'Kyoda', 'Narita', 'Seki', 'Takeuchi', 'Nakamura', 'Koyama', 'Inoue', 'Terasoma', 'Sonozaki', 'Nakamura', 'Kawanishi', 'Hirota', 'Katsuki', 'Takeuchi', 'Nakamura', 'Sugiyama', 'Ishizuka', 'Kumai', 'Inoue', 'Koyama', 'Morikubo', 'Mizuki', 'Hino', 'Kawada', 'Takeuchi', 'Nakamura', 'Inoue', 'Hino', 'Morikubo', 'Ito', 'Yuzuki', 'Toriumi', 'Mizuki', 'Kawada', 'Masukawa', 'Tochika', 'Tamura', 'Takeuchi', 'Nakamura', 'Masukawa', 'Tochika', 'Fujimura', 'Oda', 'Kishio', 'Orikasa', 'Nakamura', 'Kakihara', 'Taniyama', 'Sawashiro', 'Konishi', 'Katsuki', 'Nemoto', 'Ebara', 'Inoue', 'Morikubo', 'Park', 'Ono', 'Kato', 'Takeuchi', 'Nakamura', 'Hino', 'Koyama', ...

# %%
#Export the new dataframe as cast_df.csv to a csv file.
